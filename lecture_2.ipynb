# %% [markdown]
# <a href="https://colab.research.google.com/github/peterisT123/FullStack/blob/main/lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python pamati

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(1+4+4+4+5+5+5)
# Out:
# 28

# %% [markdown]
# #### Mainīgie

# %%
message = "Hello Python world!"
#print(message)
message = 1
#print(message)
zina = "Tests"
#print(zina)
rezultats = message +9
print(rezultats)
# Out:
# 10

# %% [markdown]
# #### Piešķiršana

# %%
x = 5
print(x)
y = x
print(y)
z = y *2
print(z)
x = (y + z) * 5
print(x)

# %% [markdown]
# #### papildus piešķiršanas operatori

# %%
x = 5
x += 2
print(x)
z = 5
z -=8
print(z)
# Out:
# 7
# -3

# %% [markdown]
# #### Daudzkārtēja piešķiršana

# %%
x, y, z = 1, 3, 5
print(x, y, z)

a, b, c = 3, 7, "Hello"
print(a,b,c)

pt,tr,rr = "a", "b" , "c"
print(pt,tr,rr)
# Out:
# 1 3 5
# 3 7 Hello
# a b c

# %% [markdown]
# #### Komentāri

# %%
# This is a comment
"""
This is a comment
written in
more than just one line
"""
print("comments")
# print(1 * 2)
# print(3)
# print(3*9)
# print("Hello!")
# Out:
# comments
# 3
# 27

# %%
#Datu tipa iegūšana

print(type(1))
print(type(1.1))
print(type(1.1e3))
print(type('alpha'))
print(type("beta"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# #### Datu tipa pārveidošana

# %%
a = 5
b = 7
a = str(a)
b = str(b)
print('teksts', a+b)
# Out:
# teksts 57

# %%
a = 5
print(a,type(a))
a = float(a)
print(a,type(a))

# %%
a = int("7")
print(a, type(a))

# %%
print('I told my friend, "Python is my favorite language!"')
print("The language 'Python' is named after Monty Python, not the snake.")
print("""
        Hello everyone!
        Python is one of the most versatile programming languages.
        It is worth learning.
        """)

# %% [markdown]
# #### Metodes

# %%
name = "john white"
print(name.title())

# %% [markdown]
# #### Virkņu metodes

# %%
name = "   George brown        "
print(name)
print("")
print(name.title(), 7)
print(name.upper(), 7)
print(name.lower(), 7)
print(name.rstrip(), 7)
print(name.lstrip(), 7)
print(name.strip(), 7)
print(name.title().strip())

# %% [markdown]
# #### Tab un jaunas rindas

# %%
print("Python")
print("\tPython")
print("Languages:\nPython\nC\nJavaScript")

# %% [markdown]
# #### f un r virknes

# %%
first_name = "ada"
last_name = "lovelace"
full_name = f"{first_name} {last_name}"
print(f"Hello, {full_name.title()}!")

# %%
dir_path = r"c:\user\tasks\new.py"
print(dir_path)
dir_path = 'c:\\user\tasks\new'
print(dir_path)
print("Hello World, \"Pyton\"")

# %% [markdown]
# #### Veselie skaitļi

# %%
print(2 + 3)
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2**2)
print(0.2 + 0.1)
print(0.2 + 3)
print(1.0 + 4)

a = 0.2 + 0.1
print(round(a, 2))

# %% [markdown]
# #### Loģiskais tips

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)

# %%
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))

# %% [markdown]
# ## Python kolekcijas

# %% [markdown]
# #### Python saraksti

# %%
a = []
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles, a)

# %%
a = [2, 3, 5.0, "hello", [1, 2, 3], {"name": "Denis"}, True]
print(a)

# %% [markdown]
# #### Saraksta elementu atlase

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles[0])
print(bicycles[1])
print(bicycles[3])
print(bicycles[-1])
message = f"My first bicycle was a {bicycles[0].title()}."
print(message)

# %% [markdown]
# #### Saraksta satura izmaiņa

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
motorcycles[0] = 'ducati'
print(motorcycles)

# %% [markdown]
# #### Elementu pievienošana sarakstam
# ##### *append(elem) – elementa pievienošana beigās*

# %%
motorcycles.append('ducati')
print(motorcycles)

motorcycles = []
motorcycles.append('honda')
motorcycles.append('yamaha')
motorcycles.append('suzuki')
print(motorcycles)

# %% [markdown]
# ##### *insert(pos, elem) – elementa pievienošana pēc pozīcijas*

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
motorcycles.insert(0, 'ducati')
print(motorcycles)

# %% [markdown]
# #### Elementu izdzēšana no saraksta
# ##### *elem = pop() – elementa izmešana no beigām (ar tā atgriešanu)*

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)
popped_motorcycle = motorcycles.pop()
print(motorcycles)
print(popped_motorcycle)

#Funkcija del darbojas līdzīgi kā piešķiršana – var izdzēst vienu elementu vai intervālu:

motorcycles = ['honda', 'yamaha', 'suzuki', 'KTM']
del motorcycles[0:2]
print(motorcycles)

# %% [markdown]
# #### Elementu izdzēšana no saraksta
# ##### *elem = pop(pos) – elementa izmešana pēc pozīcijas (var būt negatīva)*

# %%
first_owned = motorcycles.pop(0)
print(f"The first motorcycle I owned was a {first_owned.title()}.")
# remove(val) – elementa (pirmā sastaptā) izmešana pēc vērtības

motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)
motorcycles = ['honda', 'yamaha', 'ducati', 'suzuki', 'ducati']
print(motorcycles)
motorcycles.remove('ducati')
print(motorcycles)

# %% [markdown]
# #### Sarakstu kārtošana

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()
print(cars)
cars.sort(reverse=True)
print(cars)

# %%
numbers = [1, 3, 8, 0, 7, 2]
numbers.sort()
print(numbers)
numbers.sort(reverse=True)
print(numbers)

# %% [markdown]
# #### Saraksta garums

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
len(cars)

# %%
len("hello")

# %% [markdown]
# #### Vārdnīcas

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0['color'])
print(alien_0['points'])

# %% [markdown]
# #### Vārdnīcas izveidošana

# %%
#Tukšu vārdnīcu izveido vai nu, izmantojot funkciju dict, vai ar tukšām figūriekavām {}.
dictionary_1 = {}
disctionary_2 = dict()
print(dictionary_1, len(dictionary_1), type(dictionary_1))
print(disctionary_2, len(disctionary_2), type(disctionary_2))
#Ar komatiem atdalītu pāru (atslēga:vērtība) virkne figūriekavās nozīmē vārdnīcas izveidošanu.
dd = {'četri': 4 , 'divi': 2, 'trīs':3, 'viens':1}
print(dd)
print(len(dd))
print(list(dd.keys()))

# %% [markdown]
# #### Piekļūšana vārdnīcas ierakstiem

# %%
# Piekļūšana vārdnīcas ierakstiem notiek pa vienam, izmantojot atslēgu ar tādu pašu sintaksi [ ], kā ar indeksu piekļūstot saraksta elementam.
alien_0 = {'color': 'green'}
print(alien_0['color'])
alien_0 = {'color': 'green', 'points': 5}
new_points = alien_0['points']
print(f"You just earned {new_points} points!")
#Piekļūt vārdnīcas elementiem var ari izmantojot metodi get()
alien_0 = {'color': 'green', 'speed': 'slow'}
point_value = alien_0.get('color')
print(point_value)

# %% [markdown]
# #### Ierakstu pievienošana vārdnīcai

# %%
#Viena ieraksta pievienošana vārdnīcai tiek veikta ar operatoru [ ]:

dd = {}
dd[3]='three'
dd[5]='five'
print(dd)

alien_0 = {'color': 'green', 'points': 5}
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)

# %% [markdown]
# #### Ierakstu izdzēšana no vārdnīcas

# %%
# Ieraksta izdzēšanai no vārdnīcas lieto operatoru del vai metodi pop.

dd = {'četri':(4,'four'), 'divi':(2,'two'),
'trīs':(3,'three'), 'viens':(1,'one')}
del dd['divi']
dd.pop('trīs')
print(dd)

# %% [markdown]
# #### Vārdnīcas vērtību izmaiņa

# %%
# Lai izmainītu vārdnīcas vērtību,
# jānorada vārdnīcas vārdu ar atslēgu kvadrātiekavas,
# un pēc tam jauno vērtību kuru velties piešķirt tai atslēgai.

alien_0 = {'color': 'green'}
print(f"The alien is {alien_0['color']}.")
alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")

# %% [markdown]
# #### Sarakstu izmantošana ka vārdnīcas vērtības

# %%
#Sarakstos var glabāt vārdnīcas.
#Sarakstus  un vārdnīcas var izmantot ka vārdnīcas vērtības.
#Tas viss ir īpaši noderīgi darbam ar JSON.

import json
data = [{"id": ("1", "2", "3"), "name": ("bhanu", "sivanagulu"), "department": ("HR", "IT")},
           {"id": ("4", "5", "6"), "name": ("sai", "poori"), "department": ("HR", "IT")},
           {"id": ("7", "8", "9"), "name": ("teja", "gowtam"), "department": ("finance", "IT")},
           {"id": ("10", "11", "12"), "name": ("sai", "jyothi"), "department": ("business", "IT")},
            {"id": ("13", "14", "15"), "name": ("prudhvi", "nagendram"),"department": ("business", "IT")}]
final = json.dumps(data, indent=2) # convert into json
print(final) # display

# %%
frukti = []
frukti.append("abols")
frukti.append("bumbieris")
print(frukti)

# %%
import pandas as pd
file = pd.read_csv()
