# %% [markdown]
# <a href="https://colab.research.google.com/github/peterisT123/FullStack/blob/main/Trenins_pec_2_nodarbibas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(input("Kāds vecums"))
